# %% [markdown]
# # 초음파 용접 (주제 알아서 바꾸시고)
#
# ## 전호준, 장보규 상 타시구

# %% [markdown]
# 논문에 대한 설명을 적으시구

# %% [markdown]
# 오케이?

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt
import tensorflow as tf

# %% [markdown]
# ## 1. 데이터 플롯팅
# 데이터 플롯팅 결과 앞에서 부터 50000개만 사용 나머지는 버려도 무관

# %% [markdown]
# ### Ax

# %%
for i in range (1, 9 + 1):
    Data = np.loadtxt("data/signal/Result_AccX_" + str(i*6), delimiter = ",", dtype = np.float32)
    Ax = []
    for j in range(1,50000):
        Ax.append(float(Data[j]))
    plt.subplot(3,3,i)
    plt.plot(Ax,'b',label = 'Ax')
    plt.xlabel('Time (s)',fontsize=7)
    plt.ylabel('Acceleration (m/s^2)',fontsize=7)
    plt.title('Ax' + str(i*6))
    plt.grid(True)
plt.legend(loc=1,prop={'size': 7}) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ay

# %%
for i in range (1, 9 + 1):
    Data = np.loadtxt("data/signal/Result_AccY_" + str(i*6), delimiter = ",", dtype = np.float32)
    Ay = []
    for j in range(1,50000):
        Ay.append(float(Data[j]))
    plt.subplot(3,3,i)
    plt.plot(Ay,'g',label = 'Ay')
    plt.xlabel('Time (s)',fontsize=7)
    plt.ylabel('Acceleration (m/s^2)',fontsize=7)
    plt.title('Ay' + str(i*6))
    plt.grid(True)
plt.legend(loc=1,prop={'size': 7}) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Az

# %%
for i in range (1, 9 + 1):
    Data = np.loadtxt("data/signal/Result_AccZ_" + str(i*6), delimiter = ",", dtype = np.float32)
    Az = []
    for j in range(1,50000):
        Az.append(float(Data[j]))
    plt.subplot(3,3,i)
    plt.plot(Az,'r',label = 'Az')
    plt.xlabel('Time (s)',fontsize=7)
    plt.ylabel('Acceleration (m/s^2)',fontsize=7)
    plt.title('Az' + str(i*6))
    plt.grid(True)
plt.legend(loc=1,prop={'size': 7}) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cur

# %%
for i in range (1, 9 + 1):
    Data = np.loadtxt("data/signal/Result_Cur_" + str(i*6), delimiter = ",", dtype = np.float32)
    Cur = []
    for j in range(1,50000):
        Cur.append(float(Data[j]))
    plt.subplot(3,3,i)
    plt.plot(Cur,'black',label = 'Cur')
    plt.xlabel('Time (s)',fontsize=7)
    plt.ylabel('Acceleration (m/s^2)',fontsize=7)
    plt.title('Cur' + str(i*6))
    plt.grid(True)
plt.legend(loc=1,prop={'size': 7}) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Son

# %%
for i in range (1, 9 + 1):
    Data = np.loadtxt("data/signal/Result_Son_" + str(i*6), delimiter = ",", dtype = np.float32)
    Son = []
    for j in range(1,50000):
        Son.append(float(Data[j]))
    plt.subplot(3,3,i)
    plt.plot(Son,'y',label = 'Son')
    plt.xlabel('Time (s)',fontsize=7)
    plt.ylabel('Acceleration (m/s^2)',fontsize=7)
    plt.title('Son' + str(i*6))
    plt.grid(True)
plt.legend(loc=1,prop={'size': 7}) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Vol

# %%
for i in range (1, 9 + 1):
    Data = np.loadtxt("data/signal/Result_Vol_" + str(i*6), delimiter = ",", dtype = np.float32)
    Vol = []
    for j in range(1,50000):
        Vol.append(float(Data[j]))
    plt.subplot(3,3,i)
    plt.plot(Vol,'o',label = 'Vol')
    plt.xlabel('Time (s)',fontsize=7)
    plt.ylabel('Acceleration (m/s^2)',fontsize=7)
    plt.title('Vol' + str(i*6))
    plt.grid(True)
plt.legend(loc=1,prop={'size': 7}) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. 데이터 합쳐서 엑셀화 ( X_Features : Ax, Ay, Az, Cur, Son, Vol )

# %% [markdown]
# ### Ax

# %%
Ax = []
for i in range (1, 60 + 1):
    Data = np.loadtxt("data/signal/Result_AccX_" + str(i), delimiter = ",", dtype = np.float32)
    Data = Data.reshape(-1,1)
    for j in range(len(Data)):
        Ax.append(float(Data[j]))

# %% [markdown]
# ### Ay

# %%
Ay = []
for i in range (1, 60 + 1):
    Data = np.loadtxt("data/signal/Result_AccY_" + str(i), delimiter = ",", dtype = np.float32)
    Data = Data.reshape(-1,1)
    for j in range(len(Data)):
        Ay.append(float(Data[j]))

# %% [markdown]
# ### Az

# %%
Az = []
for i in range (1, 60 + 1):
    Data = np.loadtxt("data/signal/Result_AccZ_" + str(i), delimiter = ",", dtype = np.float32)
    Data = Data.reshape(-1,1)
    for j in range(len(Data)):
        Az.append(float(Data[j]))

# %% [markdown]
# ### Cur

# %%
Cur = []
for i in range (1, 60 + 1):
    Data = np.loadtxt("data/signal/Result_Cur_" + str(i), delimiter = ",", dtype = np.float32)
    Data = Data.reshape(-1,1)
    for j in range(len(Data)):
        Cur.append(float(Data[j]))

# %% [markdown]
# ### Son

# %%
Son = []
for i in range (1, 60 + 1):
    Data = np.loadtxt("data/signal/Result_Son_" + str(i), delimiter = ",", dtype = np.float32)
    Data = Data.reshape(-1,1)
    for j in range(len(Data)):
        Son.append(float(Data[j]))

# %% [markdown]
# ### Vol

# %%
Vol = []
for i in range (1, 60 + 1):
    Data = np.loadtxt("data/signal/Result_Vol_" + str(i), delimiter = ",", dtype = np.float32)
    Data = Data.reshape(-1,1)
    for j in range(len(Data)):
        Vol.append(float(Data[j]))

# %%
## 데이터 합치는 과정
data = {
    "Ax" : Ax,
    "Ay" : Ay,
    "Az" : Az,
    "Cur" : Cur,
    "Son" : Son,
    "Vol" : Vol
}
df = pd.DataFrame(data)

# %%
df.to_csv("data_all")

# %% [markdown]
# ## 3. Data size 확인 후 Labeling

# %%
data_all = np.loadtxt("data_all", delimiter=",", dtype=np.float32, skiprows=1)
x_data = data_all[:, 1:]
print(x_data.shape) ## [60 * 160000 , feature 6]
# Out:
# (9600000, 6)

# %%
y_data = np.array([[0]] * 20 + [[1]] * 20 + [[2]] * 20) # y값 Labeling (0은 정상, 1은 역용접, 2는 이중용접)
y_data.shape # training dat set m 은 60
# Out:
# (60, 1)

# %%
## scaling
def MinMaxScaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    return numerator / (denominator + 1e-7)

x_data = MinMaxScaler(x_data)

# %%
## shuffling data
x_data_temp = x_data[:160000]
y_data_temp = y_data[:1]
np.random.seed(0)
arr = np.arange(1, 60)
np.random.shuffle(arr)
for i in arr:
    x_data_temp = np.vstack((x_data_temp, x_data[i * 160000: (i+1) * 160000]))
    y_data_temp = np.vstack((y_data_temp, y_data[i: i+1]))
x_data = x_data_temp
y_data = y_data_temp

# %%
## train set, test set 나누기(원래 데이터 많을 떄는 트레이닝 데이터랑 테스트데이터랑 겹치게 안쓰는데 데이터가 너무 적어 어쩔수 없이 겹치게 씀)
x_data_train = x_data
x_data_test = x_data[:160000*10,:]
y_data_train = y_data
y_data_test = y_data[:10, :]

# %%
x_data_train = x_data_train.reshape((-1,160000,3))
x_data_test = x_data_test.reshape((-1,160000,3))

# %% [markdown]
# ## 4. LSTM

# %% [markdown]
# Compared to a classical approach, using a Recurrent Neural Networks (RNN) with Long Short-Term Memory cells (LSTMs) require no or almost no feature engineering. Data can be fed directly into the neural network who acts like a black box, modeling the problem correctly. Other research on the recognition dataset used mostly use a big amount of feature engineering, which is rather a signal processing approach combined with classical data science techniques. The approach here is rather very simple in terms of how much did the data was preprocessed.

# %% [markdown]
# ### What is an RNN?

# %% [markdown]
# As explained in this article, an RNN takes many input vectors to process them and output other vectors. It can be roughly pictured like in the image below, imagining each rectangle has a vectorial depth and other special hidden quirks in the image below. In our case, the "many to one" architecture is used: we accept time series of feature vectors (one vector per time step) to convert them to a probability vector at the output for classification. Note that a "one to one" architecture would be a standard feedforward neural network.
#
# ![Alt text](rnn1.jpg)
